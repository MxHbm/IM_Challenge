# %%
from ConstructiveHeuristic import *

# %%
# Einzelne Parameterkombinationen

instanzen = ['7_2_1', '7_2_2' ,'7_5_1', '7_5_2', '7_8_1', '7_8_2', '7_10_1', '7_10_2']

auswertungen = {}

print('______________________________________________________________________')

for i in instanzen:
    print('Instance: ' + i)
    data = InputData("../Data/Instanzen/Instance"+i+".json")


    pool = SolutionPool()
    evaluationLogic = EvaluationLogic(data)

    ConstructiveHeuristic = ConstructiveHeuristics(pool, evaluationLogic)


    ConstructiveHeuristic.Run(data, 'Greedy')

    solution = pool.GetHighestProfitSolution()
    profit = pool.GetHighestProfitSolution().TotalProfit
    print('Profit: ' + str(profit))
    numberTasks = pool.GetHighestProfitSolution().TotalTasks
    print('Number of Tasks: ' + str(numberTasks))

    solution.WriteSolToJson(data)
    print('______________________________________________________________________')
# Out:
# ______________________________________________________________________
# Instance: 7_2_1
# Generating an initial solution according to Greedy.
# Assigning main tasks to days and cohorts according to OnePerDay.
# Initial Solution found.
# Assigning main tasks to days and cohorts according to MIP.
# Calculate Distances
# Calculate Distance plus Service Times
# Set parameter Username
# Academic license - for non-commercial use only - expires 2024-11-02
# Initial Solution found.
# Assigning main tasks to days and cohorts according to OnePerDay.
# Initial Solution found.
# Profit: 739
# Number of Tasks: 262
# JSON file has been created at ../Data/Results_Greedy/solution_Instance7_2_1.json
# ______________________________________________________________________
# Instance: 7_2_2
# Generating an initial solution according to Greedy.
# Assigning main tasks to days and cohorts according to OnePerDay.
# Initial Solution found.
# Assigning main tasks to days and cohorts according to MIP.
# ...

# %%
# ParameterStudie Greedy

'''
import time

mainTaskPlanner = ['OnePerDay', 'MIP']
attractivenessFunction = ['OnlyDistanceToNextTask', 'WithDistanceToMainTask', 'WithDistanceToMainAndCloseTasks']
a_parameter = [0.5, 1, 1.5, 2]
b_parameter = [20, 50, 100]
instanzen = ['7_2_1', '7_2_2' ,'7_5_1', '7_5_2', '7_8_1', '7_8_2', '7_10_1', '7_10_2']

auswertungen = {}

print('______________________________________________________________________')

for i in instanzen:
    auswertungen[i] = []

    for mtp in mainTaskPlanner:
        for af in attractivenessFunction:
            for a in a_parameter:

                if af == 'WithDistanceToMainAndCloseTasks':
                    for b in b_parameter:
                        print('Instance: ' + i)
                        print('Main Task Planner: ' + mtp)
                        print('Attractiveness Function: ' + af)
                        print('a: ' + str(a))
                        print('b: ' + str(b))

                        data = InputData("../Data/Instanzen/Instance" + i + ".json")
                        pool = SolutionPool()
                        evaluationLogic = EvaluationLogic(data)
                        ConstructiveHeuristic = ConstructiveHeuristics(pool, evaluationLogic)

                        # Starte die Zeitmessung
                        start_time = time.time()

                        # Führe die Funktion aus
                        ConstructiveHeuristic.Run(data, 'Greedy', mainTaskPlanner=mtp, attractivenessFunction=af, a=a, b=b)

                        # Stoppe die Zeitmessung
                        end_time = time.time()

                        # Berechne die Laufzeit
                        runtime = end_time - start_time

                        print()
                        profit = pool.GetHighestProfitSolution().TotalProfit
                        print('Profit: ' + str(profit))
                        numberTasks = pool.GetHighestProfitSolution().TotalTasks
                        print('Number of Tasks: ' + str(numberTasks))
                        auswertungen[i].append([profit, numberTasks, mtp, af, a, b, runtime])

                        print('______________________________________________________________________')

                else:
                    b = 0
                    print('Instance: ' + i)
                    print('Main Task Planner: ' + mtp)
                    print('Attractiveness Function: ' + af)
                    print('a: ' + str(a))
                    print('b: ' + str(b))

                    data = InputData("../Data/Instanzen/Instance" + i + ".json")
                    pool = SolutionPool()
                    evaluationLogic = EvaluationLogic(data)
                    ConstructiveHeuristic = ConstructiveHeuristics(pool, evaluationLogic)

                    # Starte die Zeitmessung
                    start_time = time.time()

                    # Führe die Funktion aus
                    ConstructiveHeuristic.Run(data, 'Greedy', mainTaskPlanner=mtp, attractivenessFunction=af, a=a, b=b)

                    # Stoppe die Zeitmessung
                    end_time = time.time()

                    # Berechne die Laufzeit
                    runtime = end_time - start_time

                    print()
                    profit = pool.GetHighestProfitSolution().TotalProfit
                    print('Profit: ' + str(profit))
                    numberTasks = pool.GetHighestProfitSolution().TotalTasks
                    print('Number of Tasks: ' + str(numberTasks))
                    auswertungen[i].append([profit, numberTasks, mtp, af, a, b, runtime])

                    print('______________________________________________________________________')

    print('______________________________________________________________________')

'''
# Out:
# '\nimport time\n\nmainTaskPlanner = [\'OnePerDay\', \'MIP\']\nattractivenessFunction = [\'OnlyDistanceToNextTask\', \'WithDistanceToMainTask\', \'WithDistanceToMainAndCloseTasks\']\na_parameter = [0.5, 1, 1.5, 2]\nb_parameter = [20, 50, 100]\ninstanzen = [\'7_2_1\', \'7_2_2\' ,\'7_5_1\', \'7_5_2\', \'7_8_1\', \'7_8_2\', \'7_10_1\', \'7_10_2\']\n\nauswertungen = {}\n\nprint(\'______________________________________________________________________\')\n\nfor i in instanzen:\n    auswertungen[i] = []\n\n    for mtp in mainTaskPlanner:\n        for af in attractivenessFunction:\n            for a in a_parameter:\n\n                if af == \'WithDistanceToMainAndCloseTasks\':\n                    for b in b_parameter:\n                        print(\'Instance: \' + i)\n                        print(\'Main Task Planner: \' + mtp)\n                        print(\'Attractiveness Function: \' + af)\n                        print(\'a: \' + str(a))\n                        print(\'b: \' + str(b)
# ...

# %%
print(auswertungen)
# Out:
# {}

# %%
auswertungen = {"7_2_1": [[687, 257, "OnePerDay", "OnlyDistanceToNextTask", 0.5, 0, 1.164344072341919], [703, 253, "OnePerDay", "OnlyDistanceToNextTask", 1, 0, 1.1752541065216064], [704, 250, "OnePerDay", "OnlyDistanceToNextTask", 1.5, 0, 1.1056692600250244], [704, 250, "OnePerDay", "OnlyDistanceToNextTask", 2, 0, 1.1463439464569092], [718, 266, "OnePerDay", "WithDistanceToMainTask", 0.5, 0, 1.2531039714813232], [723, 258, "OnePerDay", "WithDistanceToMainTask", 1, 0, 1.2499418258666992], [723, 257, "OnePerDay", "WithDistanceToMainTask", 1.5, 0, 1.199441909790039], [723, 257, "OnePerDay", "WithDistanceToMainTask", 2, 0, 1.253587007522583], [712, 272, "OnePerDay", "WithDistanceToMainAndCloseTasks", 0.5, 20, 8.820841073989868], [724, 267, "OnePerDay", "WithDistanceToMainAndCloseTasks", 0.5, 50, 8.741890907287598], [726, 267, "OnePerDay", "WithDistanceToMainAndCloseTasks", 0.5, 100, 8.753895282745361], [726, 260, "OnePerDay", "WithDistanceToMainAndCloseTasks", 1, 20, 8.808240175247192], [732, 262, "OnePerDay", "WithDistanceToMainAndCloseTasks", 1, 50, 8.743052005767822], [734, 262, "OnePerDay", "WithDistanceToMainAndCloseTasks", 1, 100, 8.712481021881104], [733, 260, "OnePerDay", "WithDistanceToMainAndCloseTasks", 1.5, 20, 8.77297592163086], [732, 260, "OnePerDay", "WithDistanceToMainAndCloseTasks", 1.5, 50, 8.697423696517944], [722, 256, "OnePerDay", "WithDistanceToMainAndCloseTasks", 1.5, 100,
"MIP", "WithDistanceToMainAndCloseTasks", 2, 100, 25.66427206993103]], "7_10_2": [[2281, 1055, "OnePerDay", "OnlyDistanceToNextTask", 0.5, 0, 7.046332836151123], [2278, 1045, "OnePerDay", "OnlyDistanceToNextTask", 1, 0, 6.852183103561401], [2257, 1024, "OnePerDay", "OnlyDistanceToNextTask", 1.5, 0, 6.696375846862793], [2258, 1025, "OnePerDay", "OnlyDistanceToNextTask", 2, 0, 6.637793064117432], [2303, 1070, "OnePerDay", "WithDistanceToMainTask", 0.5, 0, 7.349025011062622], [2298, 1065, "OnePerDay", "WithDistanceToMainTask", 1, 0, 7.2553229331970215], [2298, 1065, "OnePerDay", "WithDistanceToMainTask", 1.5, 0, 7.1561219692230225], [2291, 1058, "OnePerDay", "WithDistanceToMainTask", 2, 0, 6.9603681564331055], [2298, 1065, "OnePerDay", "WithDistanceToMainAndCloseTasks", 0.5, 20, 16.840930938720703], [2303, 1070, "OnePerDay", "WithDistanceToMainAndCloseTasks", 0.5, 50, 16.68508005142212], [2303, 1070, "OnePerDay", "WithDistanceToMainAndCloseTasks", 0.5, 100, 16.522578954696655], [2300, 1067, "OnePerDay", "WithDistanceToMainAndCloseTasks", 1, 20, 16.40510320663452], [2298, 1065, "OnePerDay", "WithDistanceToMainAndCloseTasks", 1, 50, 16.3554470539093], [2299, 1066, "OnePerDay", "WithDistanceToMainAndCloseTasks", 1, 100, 16.6971538066864], [2294, 1061, "OnePerDay", "WithDistanceToMainAndCloseTasks", 1.5, 20, 16.560932159423828], [2296, 1063, "OnePerDay", "WithDistanceToMainAndCloseTasks", 1.5, 50, 16.097859144210815], [2297, 1064, "OnePerDay", "WithDistanceToMainAndCloseTasks", 1.5, 100, 16.218416213989258], [2285, 1052, "OnePerDay", "WithDistanceToMainAndCloseTasks", 2, 20, 16.203569173812866], [2289, 1056, "OnePerDay", "WithDistanceToMainAndCloseTasks", 2, 50, 16.2361159324646], [2287, 1054, "OnePerDay", "WithDistanceToMainAndCloseTasks", 2, 100, 16.07038426399231], [2282, 1055, "MIP", "OnlyDistanceToNextTask", 0.5, 0, 15.950490236282349], [2273, 1040, "MIP", "OnlyDistanceToNextTask", 1, 0, 15.944223165512085], [2270, 1037, "MIP", "OnlyDistanceToNextTask", 1.5, 0, 15.398967742919922], [2255, 1022, "MIP", "OnlyDistanceToNextTask", 2, 0, 15.32578992843628], [2303, 1070, "MIP", "WithDistanceToMainTask", 0.5, 0, 16.24884581565857], [2289, 1056, "MIP", "WithDistanceToMainTask", 1, 0, 15.906490087509155], [2289, 1056, "MIP", "WithDistanceToMainTask", 1.5, 0, 15.896384954452515], [2282, 1049, "MIP", "WithDistanceToMainTask", 2, 0, 15.879863023757935], [2301, 1068, "MIP", "WithDistanceToMainAndCloseTasks", 0.5, 20, 25.40080714225769], [2303, 1070, "MIP", "WithDistanceToMainAndCloseTasks", 0.5, 50, 25.564077138900757], [2303, 1070, "MIP", "WithDistanceToMainAndCloseTasks", 0.5, 100, 25.875611782073975], [2294, 1061, "MIP", "WithDistanceToMainAndCloseTasks", 1, 20, 25.91826295852661], [2290, 1057, "MIP", "WithDistanceToMainAndCloseTasks", 1, 50, 25.610201120376587], [2287, 1054, "MIP", "WithDistanceToMainAndCloseTasks", 1, 100, 25.84952712059021], [2293, 1060, "MIP", "WithDistanceToMainAndCloseTasks", 1.5, 20, 25.526758909225464], [2288, 1055, "MIP", "WithDistanceToMainAndCloseTasks", 1.5, 50, 25.327919960021973], [2291, 1058, "MIP", "WithDistanceToMainAndCloseTasks", 1.5, 100, 25.390926837921143], [2284, 1051, "MIP", "WithDistanceToMainAndCloseTasks", 2, 20, 25.47865605354309], [2284, 1051, "MIP", "WithDistanceToMainAndCloseTasks", 2, 50, 25.74081587791443], [2283, 1050, "MIP", "WithDistanceToMainAndCloseTasks", 2, 100, 25.46843910217285]]}
