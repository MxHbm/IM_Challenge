# %%
# Create DataFrame

import pandas as pd

import matplotlib.pyplot as plt

csv = pd.read_csv('7_8_1_profit_over_time.csv')

df = pd.DataFrame(csv)

# Plot the graph

plt.figure(figsize=(10, 4))
plt.plot(df['RunTime'], df['Profit'],  color='b', label='Profit over Time')
plt.title('Profit over RunTime')
plt.xlabel('RunTime (seconds)')
plt.ylabel('Profit')
plt.grid(True)
plt.legend()
plt.tight_layout()


plt.rcParams["font.family"] = "serif"

# Show the plot
plt.show()

# %%
# Berechne die Differenz der Profit-Spalte
df['Profit_Change'] = df['Profit'].diff()

# Filtere die Zeitpunkte heraus, an denen sich der Profit geändert hat
profit_changes = df[df['Profit_Change'] != 0][['RunTime', 'Profit_Change']]

# Zeige die Zeitpunkte und die Stärke der Änderungen
profit_changes['Previous_Profit'] = profit_changes['RunTime'].apply(lambda x: df.loc[df['RunTime'] == x, 'Profit'].values[0] - df.loc[df['RunTime'] == x, 'Profit_Change'].values[0])
profit_changes['New_Profit'] = profit_changes['RunTime'].apply(lambda x: df.loc[df['RunTime'] == x, 'Profit'].values[0])
print(profit_changes)
# Out:
#            RunTime  Profit_Change  Previous_Profit  New_Profit
# 0         0.000000            NaN              NaN        2087
# 1        22.914329           31.0           2087.0        2118
# 3        27.969307            2.0           2118.0        2120
# 7        35.773986            2.0           2120.0        2122
# 9        39.187084            1.0           2122.0        2123
# 12       46.263293            3.0           2123.0        2126
# 13       47.939905            1.0           2126.0        2127
# 16       53.374270            2.0           2127.0        2129
# 17       54.950698            1.0           2129.0        2130
# 26       72.326883            1.0           2130.0        2131
# 27       74.043891            1.0           2131.0        2132
# 33       83.281328            1.0           2132.0        2133
# 34       84.868593            1.0           2133.0        2134
# 57      132.213021            2.0           2134.0        2136
# 67      147.168744            1.0           2136.0        2137
# 73      155.388558            1.0           2137.0        2138
# 74      156.797597            1.0           2138.0        2139
# 82      168.104730            1.0           2139.0        2140
# 104     203.606422            1.0           2140.0        2141
# 121     231.647746            1.0           2141.0        2142
# 128     242.453558            1.0           2142.0        2143
# 143     259.011609            1.0           2143.0        2144
# 161     280.674982            1.0           2144.0        2145
# 176     295.972809            1.0           2145.0        2146
# 204     335.620933            1.0           2146.0        2147
# 220     358.242551            1.0           2147.0        2148
# 236     375.112847            1.0           2148.0        2149
# 243     381.303323            1.0           2149.0        2150
# 251     390.189481            1.0           2150.0        2151
# 292     427.425892            1.0           2151.0        2152
# 309     440.990664            1.0           2152.0        2153
# 321     451.583632            1.0           2153.0        2154
# 403     527.188370            1.0           2154.0        2155
# 436     562.027038            1.0           2155.0        2156
# 486     629.373683            1.0           2156.0        2157
# 602     741.567416            1.0           2157.0        2158
# 625     761.530485            1.0           2158.0        2159
# 747     881.375400            1.0           2159.0        2160
# 830     951.524141            1.0           2160.0        2161
# 957    1070.657549            1.0           2161.0        2162
# 1147   1274.400742            1.0           2162.0        2163
# 1369   1489.577413            1.0           2163.0        2164
# 1543   1670.622041            1.0           2164.0        2165
# 4400   5211.349387            1.0           2165.0        2166
# 5936   7993.411415            1.0           2166.0        2167
# 9199  13920.599140            1.0           2167.0        2168
