# %%
# Create DataFrame

import pandas as pd

import matplotlib.pyplot as plt

csv = pd.read_csv('7_5_1_profit_over_time.csv')

df = pd.DataFrame(csv)

# Plot the graph
plt.figure(figsize=(10, 6))
plt.plot(df['RunTime'], df['Profit'], color='b', label='Profit over Time')
plt.title('Profit over RunTime')
plt.xlabel('RunTime (seconds)')
plt.ylabel('Profit')
plt.grid(True)
plt.legend()

# choose layout
plt.tight_layout()


# Show the plot
plt.show()

# %%
# Berechne die Differenz der Profit-Spalte
df['Profit_Change'] = df['Profit'].diff()

# Filtere die Zeitpunkte heraus, an denen sich der Profit geändert hat
profit_changes = df[df['Profit_Change'] != 0][['RunTime', 'Profit_Change']]

# Zeige die Zeitpunkte und die Stärke der Änderungen
profit_changes['Previous_Profit'] = profit_changes['RunTime'].apply(lambda x: df.loc[df['RunTime'] == x, 'Profit'].values[0] - df.loc[df['RunTime'] == x, 'Profit_Change'].values[0])
profit_changes['New_Profit'] = profit_changes['RunTime'].apply(lambda x: df.loc[df['RunTime'] == x, 'Profit'].values[0])
print(profit_changes)
# Out:
#           RunTime  Profit_Change  Previous_Profit  New_Profit
# 0        0.000000            NaN              NaN        2087
# 1        4.368536           12.0           2087.0        2099
# 2        7.342750            8.0           2099.0        2107
# 3        9.640132            9.0           2107.0        2116
# 4       12.475413            5.0           2116.0        2121
# 5       15.049809            2.0           2121.0        2123
# 6       17.454417            2.0           2123.0        2125
# 7       19.837494            2.0           2125.0        2127
# 8       22.803139            3.0           2127.0        2130
# 9       25.489606            1.0           2130.0        2131
# 10      28.113058            2.0           2131.0        2133
# 11      30.745039            1.0           2133.0        2134
# 12      34.254964            4.0           2134.0        2138
# 13      37.389336            2.0           2138.0        2140
# 14      40.499083            1.0           2140.0        2141
# 15      43.656021            1.0           2141.0        2142
# 16      47.084452            2.0           2142.0        2144
# 17      49.985947            1.0           2144.0        2145
# 18      53.252085            1.0           2145.0        2146
# 19      56.564436            1.0           2146.0        2147
# 20      60.177526            1.0           2147.0        2148
# 21      64.628302            2.0           2148.0        2150
# 23      73.357553            1.0           2150.0        2151
# 25      79.966236            1.0           2151.0        2152
# 31     107.342513            2.0           2152.0        2154
# 41     151.626240            1.0           2154.0        2155
# 43     164.131773            1.0           2155.0        2156
# 50     199.249577            1.0           2156.0        2157
# 61     248.936913            1.0           2157.0        2158
# 62     254.176101            1.0           2158.0        2159
# 68     288.603534            1.0           2159.0        2160
# 83     356.704725            1.0           2160.0        2161
# 88     395.605799            1.0           2161.0        2162
# 97     450.539226            1.0           2162.0        2163
# 115    540.217455            1.0           2163.0        2164
# 125    592.245010            1.0           2164.0        2165
# 132    632.002150            1.0           2165.0        2166
# 143    692.987948            1.0           2166.0        2167
# 157    758.047325            1.0           2167.0        2168
# 160    775.925149            1.0           2168.0        2169
# 187    966.573772            1.0           2169.0        2170
# 198   1045.445264            1.0           2170.0        2171
# 236   1327.841705            1.0           2171.0        2172
# 250   1425.665497            1.0           2172.0        2173
# 268   1584.389775            1.0           2173.0        2174
# 277   1658.663210            1.0           2174.0        2175
# 281   1701.992283            1.0           2175.0        2176
# 293   1840.007377            1.0           2176.0        2177
# 562   4617.472608            1.0           2177.0        2178
# 564   4641.319983            1.0           2178.0        2179
# 676   5931.494639            1.0           2179.0        2180
# 700   6229.278206            1.0           2180.0        2181
# 738   6820.703439            1.0           2181.0        2182
# 813   7661.810085            1.0           2182.0        2183
# 832   7942.868632            1.0           2183.0        2184
# 973  10179.974284            1.0           2184.0        2185
